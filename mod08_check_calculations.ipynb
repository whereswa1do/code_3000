# %% [markdown]
# # Instructions
#
# (1) In mod08_sustainability_calculations, the energy usage is the product of the number of CPU cores, the number of runtime hours, and the number of kilowatts used per core. Update the function "compute_energy_kwh" to reflect this. _Hint_: You'll want to explore the data created in mod08_generate_emissions_data to learn the appropriate variable names.
#
# (2) After you've updated (and saved) mod08_sustainability_calculations, run the cells in this notebook and answer the three discussion question.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from mod08_generate_emissions_data import generate_data
from mod08_sustainability_calculations import (
    compute_energy_kwh,
    compute_emissions,
    emissions_by_region,
    compute_total_runtime
)

# %% [markdown]
# ### Get the data

# %%
jobs, carbon_intensity, power_per_core_kw, max_cores_per_region = generate_data()

# %% [markdown]
# ### Inspect the Provided Data

# %%
print("Jobs Dataset:")
print(jobs)

print("\nCarbon Intensity by Region (kg CO2 per kWh):")
for region, intensity in carbon_intensity.items():
    print(f"{region}: {intensity}")
# Out:
# Jobs Dataset:
#     job_id  cpu_cores  runtime_hours
# 0        1          1           0.50
# 1        2          2           1.20
# 2        3          4           0.75
# 3        4          8           2.50
# 4        5          2           1.00
# 5        6          1           0.30
# 6        7         16           3.00
# 7        8          4           1.50
# 8        9          8           2.00
# 9       10          2           0.80
# 10      11          4           0.50
# 11      12          8           2.25
# 12      13          2           1.60
# 13      14          8           0.90
# 14      15         16           1.10
#
# Carbon Intensity by Region (kg CO2 per kWh):
# coal_heavy_region: 0.9
# renewable_region: 0.05

# %% [markdown]
# ### Compute Energy Usage

# %%
jobs_with_energy = compute_energy_kwh(jobs, power_per_core_kw)

print("Jobs with Energy Computed:")
print(jobs_with_energy)

total_energy = jobs_with_energy["energy_kwh"].sum()
print(f"\nTotal Energy Consumption: {total_energy:.4f} kWh")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 jobs_with_energy = compute_energy_kwh(jobs, power_per_core_kw)
#       3 print("Jobs with Energy Computed:")
#       4 print(jobs_with_energy)
#
# File c:\Users\yanni\code_3000\mod08_sustainability_calculations.py:11, in compute_energy_kwh(jobs_df, power_per_core_kw)
#       7 """
#       8 Adds a column 'energy_kwh' to the jobs dataframe.
#       9 """
#      10 df = jobs_df.copy()
# ---> 11 df["energy_kwh"] = (
#      12     # put energy calculation here
#      13
#      14 )
#      15 return df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)   4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
#    4534         and not isinstance(value.dtype, ExtensionDtype)
#    4535     ):
#    4536         # broadcast across multiple columns if necessary
#    4537         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
#    5276     isinstance(value, Index)
#    5277     and value.dtype == "object"
#    (...)   5280     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5281     # this deprecation
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (0) does not match length of index (15)

# %% [markdown]
# ### Compute Emissions for Each Region

# %%
region_emissions = emissions_by_region(jobs_with_energy, carbon_intensity)

print("Total Emissions by Region (kg CO2):")
for region, emissions in region_emissions.items():
    print(f"{region}: {emissions:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 region_emissions = emissions_by_region(jobs_with_energy, carbon_intensity)
#       3 print("Total Emissions by Region (kg CO2):")
#       4 for region, emissions in region_emissions.items():
#
# NameError: name 'jobs_with_energy' is not defined

# %% [markdown]
# ### Visualize Emissions by Region

# %%
plt.figure()
plt.bar(region_emissions.keys(), region_emissions.values())
plt.xlabel("Region")
plt.ylabel("Total Emissions (kg CO2)")
plt.title("Carbon Emissions by Region")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 plt.figure()
# ----> 2 plt.bar(region_emissions.keys(), region_emissions.values())
#       3 plt.xlabel("Region")
#       4 plt.ylabel("Total Emissions (kg CO2)")
#
# NameError: name 'region_emissions' is not defined

# %% [markdown]
# ### Scenario 1: All Jobs in Coal-Heavy Region

# %%
coal_region = max(carbon_intensity, key=carbon_intensity.get)
all_coal_emissions = compute_emissions(
    jobs_with_energy,
    carbon_intensity[coal_region]
)

all_coal_runtime = compute_total_runtime(jobs_with_energy, max_cores_per_region[coal_region])

print(f"All jobs in {coal_region}: {all_coal_emissions:.4f} kg CO2, Runtime: {all_coal_runtime:.2f} h")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 coal_region = max(carbon_intensity, key=carbon_intensity.get)
#       2 all_coal_emissions = compute_emissions(
# ----> 3     jobs_with_energy,
#       4     carbon_intensity[coal_region]
#       5 )
#       7 all_coal_runtime = compute_total_runtime(jobs_with_energy, max_cores_per_region[coal_region])
#       9 print(f"All jobs in {coal_region}: {all_coal_emissions:.4f} kg CO2, Runtime: {all_coal_runtime:.2f} h")
#
# NameError: name 'jobs_with_energy' is not defined

# %% [markdown]
# ### Scenario 2: All Jobs in Renewable Region

# %%
renewable_region = min(carbon_intensity, key=carbon_intensity.get)
all_renewable_emissions = compute_emissions(
    jobs_with_energy,
    carbon_intensity[renewable_region]
)

all_renewable_runtime = compute_total_runtime(jobs_with_energy, max_cores_per_region[renewable_region])

print(f"All jobs in {renewable_region}: {all_renewable_emissions:.4f} kg CO2, Runtime: {all_renewable_runtime:.2f} h")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 renewable_region = min(carbon_intensity, key=carbon_intensity.get)
#       2 all_renewable_emissions = compute_emissions(
# ----> 3     jobs_with_energy,
#       4     carbon_intensity[renewable_region]
#       5 )
#       7 all_renewable_runtime = compute_total_runtime(jobs_with_energy, max_cores_per_region[renewable_region])
#       9 print(f"All jobs in {renewable_region}: {all_renewable_emissions:.4f} kg CO2, Runtime: {all_renewable_runtime:.2f} h")
#
# NameError: name 'jobs_with_energy' is not defined

# %% [markdown]
# ### Scenario 3: Assign High CPU Jobs to Renewable Region

# %%
# Decide which jobs to assign to renewable region
median = jobs_with_energy["cpu_cores"].median()

green_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] >= median]
dirty_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] < median]

# compute the new total emissions
smart_emissions = compute_emissions(green_jobs, carbon_intensity[renewable_region]) + \
                  compute_emissions(dirty_jobs, carbon_intensity[coal_region])

# compute the new total runtime (with parallelization)
smart_runtime = max(compute_total_runtime(green_jobs, max_cores_per_region[renewable_region]),
                    compute_total_runtime(dirty_jobs, max_cores_per_region[coal_region]))

print(f"High-CPU jobs to {renewable_region}: {smart_emissions:.4f} kg CO2, Runtime: {smart_runtime:.2f} h")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Decide which jobs to assign to renewable region
# ----> 2 median = jobs_with_energy["cpu_cores"].median()
#       4 green_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] >= median]
#       5 dirty_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] < median]
#
# NameError: name 'jobs_with_energy' is not defined

# %% [markdown]
# ### Strategy Comparison Plot

# %%
# Prepare data
strategy_names = ["All Coal", "All Renewable", "Smart Assignment"]
emission_values = [all_coal_emissions, all_renewable_emissions, smart_emissions]
runtime_values = [all_coal_runtime, all_renewable_runtime, smart_runtime]

# Plot
fig, ax1 = plt.subplots(figsize=(8,5))

# Bar chart for emissions
ax1.bar(strategy_names, emission_values, color='skyblue', alpha=0.7)
ax1.set_ylabel("Total Emissions (kg CO2)", color='blue')
ax1.set_xlabel("Deployment Strategy")
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_title("Emissions and Total Runtime by Deployment Strategy")

# Line chart for runtime
ax2 = ax1.twinx()
ax2.plot(strategy_names, runtime_values, color='red', marker='o', linewidth=2)
ax2.set_ylabel("Total Runtime (hours)", color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(bottom=0)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Prepare data
#       2 strategy_names = ["All Coal", "All Renewable", "Smart Assignment"]
# ----> 3 emission_values = [all_coal_emissions, all_renewable_emissions, smart_emissions]
#       4 runtime_values = [all_coal_runtime, all_renewable_runtime, smart_runtime]
#       6 # Plot
#
# NameError: name 'all_coal_emissions' is not defined

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### Similar to what we did in Scenario 3, let's look at different quantile values to decide what proportion of jobs to assign to renewable energy.

# %%
# Decide which jobs to assign to renewable region
cpu_threshold = jobs_with_energy["cpu_cores"].quantile(
    # enter a choice between 0 and 1 here
    0.6
)

green_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] >= cpu_threshold]
dirty_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] < cpu_threshold]

# compute the new total emissions
smart_emissions = compute_emissions(green_jobs, carbon_intensity[renewable_region]) + \
                  compute_emissions(dirty_jobs, carbon_intensity[coal_region])

# compute the new total runtime (with parallelization)
smart_runtime = max(compute_total_runtime(green_jobs, max_cores_per_region[renewable_region]),
                    compute_total_runtime(dirty_jobs, max_cores_per_region[coal_region]))

print(f"High-CPU jobs to {renewable_region}: {smart_emissions:.4f} kg CO2, Runtime: {smart_runtime:.2f} h")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Decide which jobs to assign to renewable region
# ----> 2 cpu_threshold = jobs_with_energy["cpu_cores"].quantile(
#       3     # enter a choice between 0 and 1 here
#       4     0.6
#       5 )
#       7 green_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] >= cpu_threshold]
#       8 dirty_jobs = jobs_with_energy[jobs_with_energy["cpu_cores"] < cpu_threshold]
#
# NameError: name 'jobs_with_energy' is not defined

# %% [markdown]
# ### Comment on what you believe is the most appropriate threshold given the tradeoff between emissions and runtime.

# %% [markdown]
# I think the best threshold is around .5 to .7. Sending the top 30-50% of CPU heavy jobs to the renewable region reduces the emissions without increasing the total runtime too much, especially considering these jobs already require more time to compute. Below a thresold of .5 you route too many jobs to the renewable region which will cause bottlenecking because of the fewer max cores. Above .7 emissions savings dimish since you're only routing a small # of jobs to renewable

# %% [markdown]
# ### In this notebook, we calculate emissions and runtimes as the inputs of our cost-benefit analysis. Name and explain at least one other cost or benefit that is not considered here.

# %% [markdown]
# A cost not considered is financial cost. The renewable energy regions may have different pricing compared to coal heavy regions, so routing strictly by CPU usage could increase operational expenses. Its also important to note that moving jobs across geographic regions introduces network overhead that could affect workloads that are time sensitive.

# %% [markdown]
# ### List at least two different stakeholders that would be affected by a strategic decision regarding the assignment of resources explored in this notebook. In your opinion, which stakeholder's interests are most compelling?

# %% [markdown]
# Type your answer here.

# %% [markdown]
# Two stakeholders that would be affected by this decision are the company operating the infrastructure and the public/environment. The company cares about cost effciency and meeting runtime SLAs, while the public has to face the effects of carbon emissions through climate change long term. In my opinion, the public's interests are most definetly most compelling since the company can absorb some cost increases.
